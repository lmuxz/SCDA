# %%
import sys
sys.path.append("../src/")
sys.path.append("../model/")

# %%
import numpy as np
import torch

from io_utils import load_dataset, load_model, model_log
from metric import performance_logloss, performance_pr_auc

from coordinate_ot_adaptation import adaptation
from labelshift_correction import build_pivot_dataset, adjust_model
from confident_feature_selection import scda
from train_utils import sample_validation_data

# %% [markdown]
# ### Kaggle

# %%
model_type = "nn" # the loaded source model type
source_version = "opt" # the version of embedding matrix & prediction model that we use

task = "kaggle"
data_type = "cate"
num_dim = 43
period = [0, 1, 2, 3]
cate_index = 8

source_domain = "source"
target_domain = "target"

ratio = 0.2
version = "scda_conf"+str(ratio)

# %% [markdown]
# ### Kaggle Adaptation

# %%
njobs = 20

for seed in range(10):
    for p in period:
        torch.manual_seed(seed)
        np.random.seed(seed)

        print("Period:", p, seed, flush=True)
        model = load_model("../model/", task, source_domain, model_type, p, source_version)
        source_train, source_train_label, source_test, source_test_label = load_dataset("../data/", 
                                                                                        task, source_domain, data_type, p)
        target_train, target_train_label, target_test, target_test_label = load_dataset("../data/", 
                                                                                        task, target_domain, data_type, p)

        # get target_factor and source_factor
        target_factor = (target_train_label[:, 1]==0).sum() / target_train_label[:, 1].sum()
        source_factor = (source_train_label[:, 1]==0).sum() / source_train_label[:, 1].sum()

        # adjusting the classifier
        model = adjust_model(model, target_factor, source_factor)

        # adjusting source train dataset
        source_train, source_train_label, source_index = build_pivot_dataset(
            source_train, source_train_label[:,1], target_factor, source_factor)

        # source and target datat undersampling
        source_train_index, _ = sample_validation_data(task, source_train_label, ratio)
        source_train = source_train[source_train_index]
        
        target_train_index, _ = sample_validation_data(task, target_train_label, ratio)
        target_train = target_train[target_train_index]
        
        # source train prediction basedline
        pred_source = model.predict(source_train)

        # init adaptation & fit & transform
        adapt = adaptation(cate_dim=cate_index, num_dim=num_dim)
        adapt.fit(target_train, source_train, lmbda=1e-1)

        target_train_trans = adapt.transform(target_train, repeat=5, njobs=njobs)

        params = {
            "model": model, 
            "valid": target_train,
            "valid_trans": target_train_trans,
            "valid_label": pred_source, 
            "cate_index": cate_index, 
            "repeat": 5,
            "feature_cluster":[[i] for i in range(target_train.shape[-1])],
            "best": None,
            "feature_mask": None,
            "n_bootstrap": 100,
            "verbose": True,
        }

        
        # greedy feature selection
        feature_mask, best_history = scda(**params)
        
        # target test transformation based on selected features
        target_test_trans = adapt.transform(target_test, repeat=20, interpolation=feature_mask, njobs=njobs)

        pred = model.predict(target_test_trans).reshape(20, -1).mean(axis=0)

        perf = performance_pr_auc(pred, target_test_label[:, 1])
        model_log("../logs/pr_auc/", task, source_domain, model_type, p, source_version, 
                 "{}: {}".format(version, perf))
        print("Target Prediction pr_auc", perf, flush=True)

        perf = performance_logloss(pred, target_test_label[:, 1])
        model_log("../logs/logloss/", task, source_domain, model_type, p, source_version, 
                 "{}: {}".format(version, perf))
        print("Target Prediction logloss", perf, flush=True)
# Out:
# Period: 0 0
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.73
# Selected Features: [34 35]
# Length: 754
# Votes Percentage: 0.61
# Selected Features: [34 35 46]
# Length: 754
# Votes Percentage: 0.37
# Selected Features: [34 35 37 46]
# Target Prediction pr_auc 0.624303247573127
# Target Prediction logloss -0.15113897732637063
# Period: 1 0
# Length: 754
# Votes Percentage: 0.98
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.91
# Selected Features: [45 47]
# Length: 754
# Votes Percentage: 0.62
# Selected Features: [45 47 49]
# Length: 754
# Votes Percentage: 0.63
# Selected Features: [45 47 48 49]
# Length: 754
# Votes Percentage: 0.76
# Selected Features: [ 8 45 47 48 49]
# Length: 754
# Votes Percentage: 0.63
# Selected Features: [ 8 40 45 47 48 49]
# Length: 754
# Votes Percentage: 0.40
# Selected Features: [ 8 35 40 45 47 48 49]
# Target Prediction pr_auc 0.653497575265429
# Target Prediction logloss -0.14906506960847604
# Period: 2 0
# Length: 754
# Votes Percentage: 0.89
# Selected Features: [8]
# Length: 754
# Votes Percentage: 0.60
# Selected Features: [ 8 49]
# Length: 754
# Votes Percentage: 0.38
# Selected Features: [ 8 37 49]
# Target Prediction pr_auc 0.6320030007904318
# Target Prediction logloss -0.1507909385431589
# Period: 3 0
# Length: 754
# Votes Percentage: 0.98
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.58
# Selected Features: [37 45]
# Length: 754
# Votes Percentage: 0.51
# Selected Features: [37 45 48]
# Length: 754
# Votes Percentage: 0.63
# Selected Features: [37 45 46 48]
# Length: 754
# Votes Percentage: 0.49
# Selected Features: [37 41 45 46 48]
# Target Prediction pr_auc 0.6177624323296866
# Target Prediction logloss -0.15730334121369716
# Period: 0 1
# Length: 754
# Votes Percentage: 0.67
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.54
# Selected Features: [34 35]
# Length: 754
# Votes Percentage: 0.71
# Selected Features: [ 8 34 35]
# Length: 754
# Votes Percentage: 0.49
# Selected Features: [ 8 34 35 45]
# Target Prediction pr_auc 0.6227307904314094
# Target Prediction logloss -0.15156703389665852
# Period: 1 1
# Length: 754
# Votes Percentage: 0.40
# Selected Features: [45]
# Target Prediction pr_auc 0.6519752570838173
# Target Prediction logloss -0.14927060072507756
# Period: 2 1
# Length: 754
# Votes Percentage: 0.64
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.99
# Selected Features: [ 8 37]
# Length: 754
# Votes Percentage: 0.34
# Selected Features: [ 8 37 49]
# Target Prediction pr_auc 0.6309823826372457
# Target Prediction logloss -0.1511710914374682
# Period: 3 1
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.45
# Selected Features: [37 47]
# Target Prediction pr_auc 0.6179168361985755
# Target Prediction logloss -0.15716965533829214
# Period: 0 2
# Length: 754
# Votes Percentage: 0.96
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.65
# Selected Features: [29 34]
# Length: 754
# Votes Percentage: 0.48
# Selected Features: [29 34 48]
# Target Prediction pr_auc 0.6233244527107971
# Target Prediction logloss -0.15104943444869567
# Period: 1 2
# Length: 754
# Votes Percentage: 0.46
# Selected Features: [45]
# Target Prediction pr_auc 0.6521047392864753
# Target Prediction logloss -0.14924495700942253
# Period: 2 2
# Length: 754
# Votes Percentage: 0.43
# Selected Features: [8]
# Target Prediction pr_auc 0.6308605714379655
# Target Prediction logloss -0.1512834743694478
# Period: 3 2
# Length: 754
# Votes Percentage: 0.39
# Selected Features: [37]
# Target Prediction pr_auc 0.6177256409999139
# Target Prediction logloss -0.1571271375516673
# Period: 0 3
# Length: 754
# Votes Percentage: 0.97
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.51
# Selected Features: [34 37]
# Length: 754
# Votes Percentage: 0.39
# Selected Features: [34 37 46]
# Target Prediction pr_auc 0.6230769491864734
# Target Prediction logloss -0.15110979773487349
# Period: 1 3
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.60
# Selected Features: [40 45]
# Length: 754
# Votes Percentage: 0.38
# Selected Features: [ 8 40 45]
# Target Prediction pr_auc 0.6514336005928679
# Target Prediction logloss -0.1496422652317575
# Period: 2 3
# Length: 754
# Votes Percentage: 0.80
# Selected Features: [8]
# Length: 754
# Votes Percentage: 0.45
# Selected Features: [ 8 37]
# Target Prediction pr_auc 0.6310363282693351
# Target Prediction logloss -0.151230493796839
# Period: 3 3
# Length: 754
# Votes Percentage: 0.86
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.42
# Selected Features: [37 45]
# Target Prediction pr_auc 0.6176277824850058
# Target Prediction logloss -0.15717088373785232
# Period: 0 4
# Length: 754
# Votes Percentage: 0.40
# Selected Features: [34]
# Target Prediction pr_auc 0.6237297798332446
# Target Prediction logloss -0.15100913244669092
# Period: 1 4
# Length: 754
# Votes Percentage: 0.90
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.39
# Selected Features: [29 45]
# Target Prediction pr_auc 0.6512907032955405
# Target Prediction logloss -0.14964794358103087
# Period: 2 4
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.60
# Selected Features: [ 8 37]
# Length: 754
# Votes Percentage: 0.39
# Selected Features: [ 8 37 45]
# Target Prediction pr_auc 0.6309104632406612
# Target Prediction logloss -0.1511777453230698
# Period: 3 4
# Length: 754
# Votes Percentage: 0.97
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.70
# Selected Features: [37 41]
# Length: 754
# Votes Percentage: 0.45
# Selected Features: [37 41 45]
# Target Prediction pr_auc 0.6177642184223011
# Target Prediction logloss -0.15718831300875358
# Period: 0 5
# Length: 754
# Votes Percentage: 0.93
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.24
# Selected Features: [34 37]
# Target Prediction pr_auc 0.6235149964266203
# Target Prediction logloss -0.15102073979454841
# Period: 1 5
# Length: 754
# Votes Percentage: 0.87
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.86
# Selected Features: [45 47]
# Length: 754
# Votes Percentage: 0.56
# Selected Features: [ 8 45 47]
# Length: 754
# Votes Percentage: 0.42
# Selected Features: [ 8 45 46 47]
# Target Prediction pr_auc 0.6505771063983303
# Target Prediction logloss -0.1499358265979785
# Period: 2 5
# Length: 754
# Votes Percentage: 0.56
# Selected Features: [8]
# Length: 754
# Votes Percentage: 0.79
# Selected Features: [ 8 37]
# Length: 754
# Votes Percentage: 0.72
# Selected Features: [ 8 29 37]
# Length: 754
# Votes Percentage: 0.35
# Selected Features: [ 5  8 29 37]
# Target Prediction pr_auc 0.6306030404355901
# Target Prediction logloss -0.15129842449505462
# Period: 3 5
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.87
# Selected Features: [37 48]
# Length: 754
# Votes Percentage: 0.27
# Selected Features: [37 48 49]
# Target Prediction pr_auc 0.6185783090179408
# Target Prediction logloss -0.15713573308168138
# Period: 0 6
# Length: 754
# Votes Percentage: 0.79
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.42
# Selected Features: [34 37]
# Target Prediction pr_auc 0.6236884485664811
# Target Prediction logloss -0.15098634747094067
# Period: 1 6
# Length: 754
# Votes Percentage: 0.99
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.55
# Selected Features: [45 47]
# Length: 754
# Votes Percentage: 0.29
# Selected Features: [45 47 49]
# Target Prediction pr_auc 0.650288032256393
# Target Prediction logloss -0.15001668471729043
# Period: 2 6
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.96
# Selected Features: [ 8 37]
# Length: 754
# Votes Percentage: 0.85
# Selected Features: [ 8 37 45]
# Length: 754
# Votes Percentage: 0.68
# Selected Features: [ 8 37 45 47]
# Length: 754
# Votes Percentage: 0.45
# Selected Features: [ 8 37 45 47 49]
# Target Prediction pr_auc 0.6290091783884687
# Target Prediction logloss -0.1524850757003344
# Period: 3 6
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.38
# Selected Features: [37 48]
# Target Prediction pr_auc 0.6176160285378174
# Target Prediction logloss -0.15716918514639083
# Period: 0 7
# Length: 754
# Votes Percentage: 0.85
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.61
# Selected Features: [34 37]
# Length: 754
# Votes Percentage: 0.34
# Selected Features: [34 37 48]
# Target Prediction pr_auc 0.623016116890803
# Target Prediction logloss -0.1511296582359247
# Period: 1 7
# Length: 754
# Votes Percentage: 0.93
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.33
# Selected Features: [37 45]
# Target Prediction pr_auc 0.6512896705101915
# Target Prediction logloss -0.14962251029765944
# Period: 2 7
# Length: 754
# Votes Percentage: 0.66
# Selected Features: [8]
# Length: 754
# Votes Percentage: 0.24
# Selected Features: [ 8 37]
# Target Prediction pr_auc 0.6306617053675954
# Target Prediction logloss -0.15133593316278451
# Period: 3 7
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.73
# Selected Features: [37 48]
# Length: 754
# Votes Percentage: 0.58
# Selected Features: [37 45 48]
# Length: 754
# Votes Percentage: 0.35
# Selected Features: [37 45 46 48]
# Target Prediction pr_auc 0.6185142135669994
# Target Prediction logloss -0.15724379856812082
# Period: 0 8
# Length: 754
# Votes Percentage: 0.97
# Selected Features: [34]
# Length: 754
# Votes Percentage: 0.49
# Selected Features: [34 35]
# Target Prediction pr_auc 0.6230392413834879
# Target Prediction logloss -0.15113538343943908
# Period: 1 8
# Length: 754
# Votes Percentage: 0.97
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.44
# Selected Features: [37 45]
# Target Prediction pr_auc 0.6513926191074373
# Target Prediction logloss -0.1496025229278329
# Period: 2 8
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [ 8 37]
# Length: 754
# Votes Percentage: 0.36
# Selected Features: [ 8 37 47]
# Target Prediction pr_auc 0.630985085473526
# Target Prediction logloss -0.15125984133360132
# Period: 3 8
# Length: 754
# Votes Percentage: 0.43
# Selected Features: [45]
# Target Prediction pr_auc 0.6180066922525211
# Target Prediction logloss -0.15717802855147694
# Period: 0 9
# Length: 754
# Votes Percentage: 0.39
# Selected Features: [8]
# Target Prediction pr_auc 0.6236225091794819
# Target Prediction logloss -0.15099363906973115
# Period: 1 9
# Length: 754
# Votes Percentage: 0.96
# Selected Features: [45]
# Length: 754
# Votes Percentage: 0.76
# Selected Features: [45 47]
# Length: 754
# Votes Percentage: 0.46
# Selected Features: [ 8 45 47]
# Target Prediction pr_auc 0.6499485204611445
# Target Prediction logloss -0.15015608783252613
# Period: 2 9
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.45
# Selected Features: [ 8 37]
# Target Prediction pr_auc 0.6310697044728183
# Target Prediction logloss -0.15116293302163827
# Period: 3 9
# Length: 754
# Votes Percentage: 1.00
# Selected Features: [37]
# Length: 754
# Votes Percentage: 0.70
# Selected Features: [37 47]
# Length: 754
# Votes Percentage: 0.69
# Selected Features: [37 45 47]
# Length: 754
# Votes Percentage: 0.50
# Selected Features: [37 41 45 47]
# Length: 754
# Votes Percentage: 0.67
# Selected Features: [37 41 45 47 48]
# Length: 754
# Votes Percentage: 0.48
# Selected Features: [37 41 45 47 48 49]
# Target Prediction pr_auc 0.6182839361655467
# Target Prediction logloss -0.1574143625386598
